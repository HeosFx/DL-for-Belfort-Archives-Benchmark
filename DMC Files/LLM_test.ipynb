# %%
from transformers import AutoProcessor, LlavaForConditionalGeneration
from PIL import Image
from accelerate import infer_auto_device_map

# %%
import torch

torch.cuda.is_available()
# Out:
# True

# %%
torch.cuda.device_count()
# Out:
# 1

# %%
torch.cuda.current_device()
# Out:
# 0

# %%
torch.cuda.get_device_name(0)
# Out:
# 'NVIDIA GeForce RTX 3060 Ti'

# %%
torch.cuda.empty_cache()
print(f"Available VRAM: {torch.cuda.memory_allocated() / 1e9:.2f} GB")
# Out:
# Available VRAM: 4.94 GB

# %%
torch.cuda.empty_cache()

model_id = "mistral-community/pixtral-12b"
# Load processor
processor = AutoProcessor.from_pretrained(model_id)

# Load model with automatic device placement
model = LlavaForConditionalGeneration.from_pretrained(
    model_id,
    device_map="auto",  # Automatically place layers on GPU/CPU as needed
    torch_dtype=torch.float16  # Use FP16 for lower VRAM usage
)
# Out:
# Loading checkpoint shards:   0%|          | 0/6 [00:00<?, ?it/s]
# The model weights are not tied. Please use the `tie_weights` method before using the `infer_auto_device` function.
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 7
#       5 model = LlavaForConditionalGeneration.from_pretrained(model_id, torch_dtype=torch.float16)
#       6 device_map = infer_auto_device_map(model)
# ----> 7 model.to(device_map)
#
# File ~\miniconda3\envs\DL-for-Belfort-Archives-Benchmark\lib\site-packages\transformers\modeling_utils.py:3110, in PreTrainedModel.to(self, *args, **kwargs)
#    3105     if dtype_present_in_args:
#    3106         raise ValueError(
#    3107             "You cannot cast a GPTQ model in a new `dtype`. Make sure to load the model using `from_pretrained` using the desired"
#    3108             " `dtype` by passing the correct `torch_dtype` argument."
#    3109         )
# -> 3110 return super().to(*args, **kwargs)
#
# File ~\miniconda3\envs\DL-for-Belfort-Archives-Benchmark\lib\site-packages\torch\nn\modules\module.py:1299, in Module.to(self, *args, **kwargs)
#    1213 def to(self, *args, **kwargs):
#    1214     r"""Move and/or cast the parameters and buffers.
#    1215
#    1216     This can be called as
#    (...)
#    1297
#    1298     """
# -> 1299     device, dtype, non_blocking, convert_to_format = torch._C._nn._parse_to(
#    1300         *args, **kwargs
#    1301     )
#    1303     if dtype is not None:
#    1304         if not (dtype.is_floating_point or dtype.is_complex):
#
# TypeError: to() received an invalid combination of arguments - got (collections.OrderedDict), but expected one of:
#  * (torch.device device = None, torch.dtype dtype = None, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (torch.dtype dtype, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
#  * (Tensor tensor, bool non_blocking = False, bool copy = False, *, torch.memory_format memory_format = None)
