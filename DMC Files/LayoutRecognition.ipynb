# %%
import layoutparser as lp
import cv2

# %%
# Convert the image from BGR (cv2 default loading style)
# to RGB
image = cv2.imread("images/IMG_0217.jpg")
image = image[..., ::-1]
image.shape
# Out:
# (2145, 2638, 3)

# %%
# Load the deep layout model from the layoutparser API 
# For all the supported model, please check the Model 
# Zoo Page: https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html
model = lp.models.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config', 
                                 extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
                                 label_map={0: "Name", 1: "Surname", 2: "Date of Birth", 3:"Place of Birth", 4:"Nationality", 5:"City", 6:"Adress", 7:"Occupation"})
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[3], line 4
#       1 # Load the deep layout model from the layoutparser API
#       2 # For all the supported model, please check the Model
#       3 # Zoo Page: https://layout-parser.readthedocs.io/en/latest/notes/modelzoo.html
# ----> 4 model = lp.models.Detectron2LayoutModel('lp://PubLayNet/faster_rcnn_R_50_FPN_3x/config',
#       5                                  extra_config=["MODEL.ROI_HEADS.SCORE_THRESH_TEST", 0.8],
#       6                                  label_map={0: "Name", 1: "Surname", 2: "Date of Birth", 3:"Place of Birth", 4:"Nationality", 5:"City", 6:"Adress", 7:"Occupation"})
#
# File ~\miniconda3\envs\DL-for-Belfort-Archives-Benchmark\lib\site-packages\layoutparser\models\base_layoutmodel.py:87, in BaseLayoutModel.__new__(cls, *args, **kwargs)
#      85 def __new__(cls, *args, **kwargs):
# ...
